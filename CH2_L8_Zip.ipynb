# %%
valid_formats = [
    "docx",
    "pdf",
    "txt",
    "pptx",
    "ppt",
    "md",
]

# Don't edit above this line


def pair_document_with_format(doc_names, doc_formats):
    zipped = list(zip(doc_names, doc_formats))
    return list(filter(lambda x: x[1] in valid_formats, zipped))

doc_names = ['Proposal', 'Invoice', 'Contract']
doc_formats = ['docx', 'pdoof', 'txt']

pair_document_with_format(doc_names, doc_formats)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      17 doc_names = ['Proposal', 'Invoice', 'Contract']
#      18 doc_formats = ['docx', 'pdoof', 'txt']
# ---> 20 pair_document_with_format(doc_names, doc_formats)
#
# Cell In[1], line 14, in pair_document_with_format(doc_names, doc_formats)
#      13 def pair_document_with_format(doc_names, doc_formats):
# ---> 14     final = list(filter(valid_formats,zip(doc_names, doc_formats)))
#      15     print(final)
#
# TypeError: 'list' object is not callable

# %%
valid_formats = [
    "docx",
    "pdf",
    "txt",
    "pptx",
    "ppt",
    "md",
]

# Don't edit above this line


def pair_document_with_format(doc_names, doc_formats):
    final = list(zip(doc_names, doc_formats))
    return list(filter(lambda x: x[1] in valid_formats, final))

doc_names = ['Proposal', 'Invoice', 'Contract']
doc_formats = ['docx', 'pdoof', 'txt']

pair_document_with_format(doc_names, doc_formats)
# Out:
# [('Proposal', 'docx'), ('Contract', 'txt')]
